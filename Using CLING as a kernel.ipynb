# %%
TH1F h = TH1F("sdf", "sdf",10,0,1)
# Out:
# (TH1F &) Name: sdf Title: sdf NbinsX: 10

# %%
h.Draw()
# Out:
# Info in <TCanvas::MakeDefCanvas>:  created default TCanvas with name c1

# %%
c1->Draw()
